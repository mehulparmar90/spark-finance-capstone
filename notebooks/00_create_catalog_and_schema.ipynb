-- %%
-- Create catalog for the project
CREATE CATALOG IF NOT EXISTS finance_lakehouse;

-- %%
-- Use the catalog
USE CATALOG finance_lakehouse;

-- %%
-- Create schemas for medallion architecture
CREATE SCHEMA IF NOT EXISTS bronze
  COMMENT 'Raw ingestion layer - data as received from sources';

-- %%
CREATE SCHEMA IF NOT EXISTS silver
  COMMENT 'Cleansed and validated data layer';

-- %%
CREATE SCHEMA IF NOT EXISTS gold
  COMMENT 'Business-level aggregations and analytics';

-- %%
-- Verify
SHOW SCHEMAS IN finance_lakehouse
